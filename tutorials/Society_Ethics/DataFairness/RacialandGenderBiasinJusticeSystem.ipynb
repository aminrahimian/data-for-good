# %% [markdown]
# ### Racial Bias in Criminal Reoffending Algorithms

# %% [markdown]
# This files shows the results of an R Studio File on data relating to  algorithms that predict how likely aa criminal is to reoffend.
#
# Rcode:"RacialBiasPredict.csv"

# %% [markdown]
# To start, the value 4 values referenced are Hits, Misses, False Alarms, and Correct Rejections.  This is based off of the data of who the algorithms thought would commit another crimeand whether they actuallty committed a crime.

# %% [markdown]
# Listed below is the comparison of white participants and black patricipants

# %% [markdown]
# ![plot.png](attachment:plot.png)![plot-2.png](attachment:plot-2.png)

# %% [markdown]
# Below of the comparison of Male and Female participants

# %% [markdown]
# ![plot.png](attachment:plot.png)|![plot-2.png](attachment:plot-2.png)

# %% [markdown]
# Same thing done below, but comparing male and female

# %% [markdown]
# ![plot.png](attachment:plot.png)![plot-2.png](attachment:plot-2.png)

# %% [markdown]
# ![plot.png](attachment:plot.png)![plot-2.png](attachment:plot-2.png)

# %% [markdown]
# Below are the False Alarm and Miss rates for White Males, Black Males, White Females, and Black Females

# %% [markdown]
# ![plot.png](attachment:plot.png)![plot-2.png](attachment:plot-2.png)
